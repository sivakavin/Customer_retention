# %% [markdown]
# ### Customer Rentation :
#
# Data Scientists have to apply their analytical skills to give findings and conclusions in detailed data analysis written in jupyter notebook . Only data analysis is required.

# %%
# importing required lib
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#Classification libraries
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

#Performance check
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
# Reading the dataset
pd.set_option("display.max_columns",None)
dataset = pd.read_excel("Datasets/customer_retention_dataset_raw.xlsx")
dataset.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# 1                              Above 4 years
# 2                                  3-4 years
# 3                                  3-4 years
# 4                                  2-3 years
#
#   6 How many times you have made an online purchase in the past 1 year?  \
# 0                                        31-40 times
# 1                                 41 times and above
# 2                                 41 times and above
# 3                                 Less than 10 times
# 4                                        11-20 times
#
#   7 How do you access the internet while shopping on-line?  \
# 0                                            Dial-up
# 1                                              Wi-Fi
# 2                                    Mobile Internet
# 3                                    Mobile Internet
# 4                                              Wi-Fi
#
#   8 Which device do you use to access the online shopping?  \
# 0                                            Desktop
# 1                                         Smartphone
# 2                                         Smartphone
# 3                                         Smartphone
# 4                                         Smartphone
#
#   9 What is the screen size of your mobile device?\t\t\t\t\t\t                                          \
# 0                                             Others
# 1                                         4.7 inches
# 2                                         5.5 inches
# 3                                         5.5 inches
# 4                                         4.7 inches
#
#   10 What is the operating system (OS) of your device?\t\t\t\t                                            \
# 0                              Window/windows Mobile
# 1                                            IOS/Mac
# 2                                            Android
# 3                                            IOS/Mac
# 4                                            IOS/Mac
#
#   11 What browser do you run on your device to access the website?\t\t\t                                                            \
# 0                                      Google chrome
# 1                                      Google chrome
# 2                                      Google chrome
# 3                                             Safari
# 4                                             Safari
#
#   12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                     \
# 0                                      Search Engine
# 1                                      Search Engine
# 2                                      Search Engine
# 3                                      Search Engine
# 4                                  Content Marketing
#
#   13 After first visit, how do you reach the online retail store?\t\t\t\t                                                     \
# 0                                      Search Engine
# 1                                    Via application
# 2                                    Via application
# 3                                      Search Engine
# 4                                    Via application
#
#   14 How much time do you explore the e- retail store before making a purchase decision?                                                                     \
# 0                                          6-10 mins
# 1                                  more than 15 mins
# 2                                         11-15 mins
# 3                                          6-10 mins
# 4                                  more than 15 mins
#
#   15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                                 \
# 0                 E-wallets (Paytm, Freecharge etc.)
# 1                                 Credit/Debit cards
# 2                 E-wallets (Paytm, Freecharge etc.)
# 3                                 Credit/Debit cards
# 4                                 Credit/Debit cards
#
#   16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                     \
# 0                                          Sometimes
# 1                                    Very frequently
# 2                                          Sometimes
# 3                                              Never
# 4                                         Frequently
#
#   17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                         \
# 0                                      Lack of trust
# 1                          Promo code not applicable
# 2                          Promo code not applicable
# 3                           Better alternative offer
# 4                           Better alternative offer
#
#   18 The content on the website must be easy to read and understand  \
# 0                                          Agree (4)
# 1                                 Strongly agree (5)
# 2                                 Strongly agree (5)
# 3                                          Agree (4)
# 4                                 Strongly agree (5)
#
#   19 Information on similar product to the one highlighted  is important for product comparison  \
# 0                                    Indifferent (3)
# 1                                 Strongly agree (5)
# 2                                          Agree (4)
# 3                                          Agree (4)
# 4                                    Indifferent (3)
#
#   20 Complete information on listed seller and product being offered is important for purchase decision.  \
# 0                                    Indifferent (3)
# 1                                 Strongly agree (5)
# 2                                          Agree (4)
# 3                                    Indifferent (3)
# 4                                    Indifferent (3)
#
#   21 All relevant information on listed products must be stated clearly  \
# 0                                          Agree (4)
# 1                                 Strongly agree (5)
# 2                                          Agree (4)
# 3                                          Agree (4)
# 4                                          Agree (4)
#
#   22 Ease of navigation in website 23 Loading and processing speed  \
# 0                        Agree (4)           Strongly disagree (1)
# 1               Strongly agree (5)              Strongly agree (5)
# 2                        Agree (4)                       Agree (4)
# 3               Strongly agree (5)                       Agree (4)
# 4                        Agree (4)              Strongly agree (5)
#
#   24 User friendly Interface of the website 25 Convenient Payment methods  \
# 0                             Dis-agree (2)                 Dis-agree (2)
# 1                        Strongly agree (5)            Strongly agree (5)
# 2                        Strongly agree (5)            Strongly agree (5)
# 3                        Strongly agree (5)            Strongly agree (5)
# 4                        Strongly agree (5)            Strongly agree (5)
#
#   26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time  \
# 0                                       Disagree (2)
# 1                                 Strongly agree (5)
# 2                                 Strongly agree (5)
# 3                                          Agree (4)
# 4                                          Agree (4)
#
#   27 Empathy (readiness to assist with queries) towards the customers  \
# 0                                 Strongly agree (5)
# 1                                 Strongly agree (5)
# 2                                 Strongly agree (5)
# 3                                 Strongly agree (5)
# 4                                 Strongly agree (5)
#
#   28 Being able to guarantee the privacy of the customer  \
# 0                                          Agree (4)
# 1                                 Strongly agree (5)
# 2                                 Strongly agree (5)
# 3                                 Strongly agree (5)
# 4                                          Agree (4)
#
#   29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)  \
# 0                                          Agree (4)
# 1                                 Strongly agree (5)
# 2                                 Strongly agree (5)
# 3                                          Agree (4)
# 4                                 Strongly agree (5)
#
#   30 Online shopping gives monetary benefit and discounts  \
# 0                                    indifferent (3)
# 1                                 Strongly agree (5)
# 2                                 Strongly agree (5)
# 3                                          Agree (4)
# 4                                 Strongly agree (5)
#
#   31 Enjoyment is derived from shopping online  \
# 0                        Strongly disagree (1)
# 1                           Strongly agree (5)
# 2                           Strongly agree (5)
# 3                              indifferent (3)
# 4                           Strongly agree (5)
#
#   32 Shopping online is convenient and flexible  \
# 0                                 Dis-agree (2)
# 1                            Strongly agree (5)
# 2                            Strongly agree (5)
# 3                               indifferent (3)
# 4                            Strongly agree (5)
#
#   33 Return and replacement policy of the e-tailer is important for purchase decision  \
# 0                                      Dis-agree (2)
# 1                                 Strongly agree (5)
# 2                                 Strongly agree (5)
# 3                                          Agree (4)
# 4                                 Strongly agree (5)
#
#   34 Gaining access to loyalty programs is a benefit of shopping online  \
# 0                                          Agree (4)
# 1                                 Strongly agree (5)
# 2                                 Strongly agree (5)
# 3                                    indifferent (3)
# 4                                      Dis-agree (2)
#
#   35 Displaying quality Information on the website improves satisfaction of customers  \
# 0                                    indifferent (3)
# 1                                 Strongly agree (5)
# 2                                 Strongly agree (5)
# 3                                    indifferent (3)
# 4                                          Agree (4)
#
#   36 User derive satisfaction while shopping on a good quality website or application  \
# 0                                 Strongly agree (5)
# 1                                 Strongly agree (5)
# 2                                 Strongly agree (5)
# 3                                          Agree (4)
# 4                                 Strongly agree (5)
#
#   37 Net Benefit derived from shopping online can lead to users satisfaction  \
# 0                                          Agree (4)
# 1                                 Strongly agree (5)
# 2                                 Strongly agree (5)
# 3                                    indifferent (3)
# 4                                 Strongly agree (5)
#
#   38 User satisfaction cannot exist without trust  \
# 0                              Strongly agree (5)
# 1                              Strongly agree (5)
# 2                                       Agree (4)
# 3                                       Agree (4)
# 4                              Strongly agree (5)
#
#   39 Offering a wide variety of listed product in several category  \
# 0                                    indifferent (3)
# 1                                 Strongly agree (5)
# 2                                 Strongly agree (5)
# 3                                          Agree (4)
# 4                                          Agree (4)
#
#   40 Provision of complete and relevant product information  \
# 0                                    indifferent (3)
# 1                                 Strongly agree (5)
# 2                                 Strongly agree (5)
# 3                                          Agree (4)
# 4                                          Agree (4)
#
#   41 Monetary savings 42 The Convenience of patronizing the online retailer  \
# 0        Disagree (2)                                    indifferent (3)
# 1  Strongly agree (5)                                    indifferent (3)
# 2  Strongly agree (5)                                          Agree (4)
# 3  Strongly agree (5)                                          Agree (4)
# 4  Strongly agree (5)                                          Agree (4)
#
#   43 Shopping on the website gives you the sense of adventure  \
# 0                                          Agree (4)
# 1                                    indifferent (3)
# 2                                          Agree (4)
# 3                                          Agree (4)
# 4                                    indifferent (3)
#
#   44 Shopping on your preferred e-tailer enhances your social status  \
# 0                                          Agree (4)
# 1                                    indifferent (3)
# 2                                          Agree (4)
# 3                                 Strongly agree (5)
# 4                              Strongly disagree (1)
#
#   45 You feel gratification shopping on your favorite e-tailer  \
# 0                                 Strongly agree (5)
# 1                                 Strongly agree (5)
# 2                                    indifferent (3)
# 3                                          Agree (4)
# 4                                 Strongly agree (5)
#
#   46 Shopping on the website helps you fulfill certain roles  \
# 0                                          Agree (4)
# 1                                 Strongly agree (5)
# 2                                    indifferent (3)
# 3                                    indifferent (3)
# 4                              Strongly disagree (1)
#
#   47 Getting value for money spent  \
# 0               Strongly agree (5)
# 1               Strongly agree (5)
# 2                        Agree (4)
# 3                        Agree (4)
# 4               Strongly agree (5)
#
#   From the following, tick any (or all) of the online retailers you have shopped from;                                                                             \
# 0                               Amazon.in, Paytm.com
# 1  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 2                   Amazon.in, Paytm.com, Myntra.com
# 3  Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# 4  Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
#
#                   Easy to use website or application  \
# 0                                          Paytm.com
# 1  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 2                   Amazon.in, Paytm.com, Myntra.com
# 3  Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# 4  Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
#
#                     Visual appealing web-page layout  \
# 0                                       Flipkart.com
# 1                              Amazon.in, Myntra.com
# 2                   Amazon.in, Paytm.com, Myntra.com
# 3  Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# 4                                         Myntra.com
#
#   Wild variety of product on offer  \
# 0                     Flipkart.com
# 1         Flipkart.com, Myntra.com
# 2            Amazon.in, Myntra.com
# 3          Amazon.in, Flipkart.com
# 4                       Myntra.com
#
#   Complete, relevant description information of products  \
# 0                                       Snapdeal.com
# 1                Amazon.in, Flipkart.com, Myntra.com
# 2                   Amazon.in, Paytm.com, Myntra.com
# 3                            Amazon.in, Flipkart.com
# 4  Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
#
#   Fast loading website speed of website and application  \
# 0                                       Snapdeal.com
# 1                Amazon.in, Flipkart.com, Myntra.com
# 2                               Amazon.in, Paytm.com
# 3              Amazon.in, Flipkart.com, Snapdeal.com
# 4                                          Amazon.in
#
#   Reliability of the website or application  \
# 0                                 Paytm.com
# 1                                Myntra.com
# 2          Amazon.in, Paytm.com, Myntra.com
# 3        Amazon.in, Flipkart.com, Paytm.com
# 4          Amazon.in, Paytm.com, Myntra.com
#
#                       Quickness to complete purchase  \
# 0                                          Paytm.com
# 1               Amazon.com, Flipkart.com, Myntra.com
# 2                  Amazon.com, Paytm.com, Myntra.com
# 3                Amazon.com, Flipkart.com, Paytm.com
# 4  Amazon.com, Flipkart.com, Paytm.com, Myntra.co...
#
#              Availability of several payment options  \
# 0                                          Patym.com
# 1                Amazon.in, Flipkart.com, Myntra.com
# 2                              Patym.com, Myntra.com
# 3                Amazon.in, Flipkart.com, Myntra.com
# 4  Amazon.in, Flipkart.com, Patym.com, Myntra.com...
#
#                   Speedy order delivery     Privacy of customers’ information  \
# 0                              Amazon.in                            Amazon.in
# 1                Amazon.in, Flipkart.com                           Myntra.com
# 2                              Amazon.in                            Amazon.in
# 3  Amazon.in, Flipkart.com, Snapdeal.com  Amazon.in, Flipkart.com, Myntra.com
# 4                              Amazon.in                 Amazon.in, Paytm.com
#
#   Security of customer financial information  \
# 0                                  Amazon.in
# 1                                 Myntra.com
# 2           Amazon.in, Paytm.com, Myntra.com
# 3      Amazon.in, Flipkart.com, Snapdeal.com
# 4                                  Paytm.com
#
#                Perceived Trustworthiness  \
# 0                           Flipkart.com
# 1                             Myntra.com
# 2                  Amazon.in, Myntra.com
# 3  Amazon.in, Flipkart.com, Snapdeal.com
# 4                  Amazon.in, Myntra.com
#
#   Presence of online assistance through multi-channel  \
# 0                                          Paytm.com
# 1                Amazon.in, Flipkart.com, Myntra.com
# 2                                         Myntra.com
# 3      Amazon.in, Flipkart.com, Myntra.com, Snapdeal
# 4                              Amazon.in, Myntra.com
#
#   Longer time to get logged in (promotion, sales period)  \
# 0                                          Amazon.in
# 1                            Amazon.in, Flipkart.com
# 2                                         Myntra.com
# 3                                       Snapdeal.com
# 4                            Flipkart.com, Paytm.com
#
#   Longer time in displaying graphics and photos (promotion, sales period)  \
# 0                                          Amazon.in
# 1                                         Myntra.com
# 2                                         Myntra.com
# 3                           Myntra.com, Snapdeal.com
# 4                                          Paytm.com
#
#   Late declaration of price (promotion, sales period)  \
# 0                                       Flipkart.com
# 1                                       snapdeal.com
# 2                                         Myntra.com
# 3                                         Myntra.com
# 4                                          Paytm.com
#
#   Longer page loading time (promotion, sales period)  \
# 0                                       Flipkart.com
# 1                                       Snapdeal.com
# 2                                         Myntra.com
# 3                                          Paytm.com
# 4                                          Paytm.com
#
#   Limited mode of payment on most products (promotion, sales period)  \
# 0                                          Amazon.in
# 1                                       Snapdeal.com
# 2                                          Amazon.in
# 3                                          Paytm.com
# 4                                       Snapdeal.com
#
#   Longer delivery period Change in website/Application design  \
# 0              Paytm.com                         Flipkart.com
# 1           Snapdeal.com                            Amazon.in
# 2              Paytm.com                            Paytm.com
# 3              Paytm.com              Amazon.in, Flipkart.com
# 4              Paytm.com                            Amazon.in
#
#   Frequent disruption when moving from one page to another  \
# 0                                          Amazon.in
# 1                                         Myntra.com
# 2                                          Paytm.com
# 3                            Amazon.in, Flipkart.com
# 4                                       Snapdeal.com
#
#     Website is as efficient as before  \
# 0                           Amazon.in
# 1             Amazon.in, Flipkart.com
# 2                           Amazon.in
# 3  Amazon.in, Flipkart.com, Paytm.com
# 4                           Paytm.com
#
#   Which of the Indian online retailer would you recommend to a friend?
# 0                                       Flipkart.com
# 1                              Amazon.in, Myntra.com
# 2                   Amazon.in, Paytm.com, Myntra.com
# 3                            Amazon.in, Flipkart.com
# 4                              Amazon.in, Myntra.com

# %%
# Checking the column having what are feature
print("Feature Names :\n",dataset.columns)
# Out:
# Feature Names :
#  Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
#        '13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ',
#        '14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ',
#        '15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ',
#        '16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ',
#        '17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ',
#        '18 The content on the website must be easy to read and understand',
#        '19 Information on similar product to the one highlighted  is important for product comparison',
#        '20 Complete information on listed seller and product being offered is important for purchase decision.',
#        '21 All relevant information on listed products must be stated clearly',
#        '22 Ease of navigation in website', '23 Loading and processing speed',
#        '24 User friendly Interface of the website',
#        '25 Convenient Payment methods',
#        '26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time',
#        '27 Empathy (readiness to assist with queries) towards the customers',
#        '28 Being able to guarantee the privacy of the customer',
#        '29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)',
#        '30 Online shopping gives monetary benefit and discounts',
#        '31 Enjoyment is derived from shopping online',
#        '32 Shopping online is convenient and flexible',
#        '33 Return and replacement policy of the e-tailer is important for purchase decision',
#        '34 Gaining access to loyalty programs is a benefit of shopping online',
#        '35 Displaying quality Information on the website improves satisfaction of customers',
#        '36 User derive satisfaction while shopping on a good quality website or application',
#        '37 Net Benefit derived from shopping online can lead to users satisfaction',
#        '38 User satisfaction cannot exist without trust',
#        '39 Offering a wide variety of listed product in several category',
#        '40 Provision of complete and relevant product information',
#        '41 Monetary savings',
#        '42 The Convenience of patronizing the online retailer',
#        '43 Shopping on the website gives you the sense of adventure',
#        '44 Shopping on your preferred e-tailer enhances your social status',
#        '45 You feel gratification shopping on your favorite e-tailer',
#        '46 Shopping on the website helps you fulfill certain roles',
#        '47 Getting value for money spent',
#        'From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ',
#        'Easy to use website or application',
#        'Visual appealing web-page layout', 'Wild variety of product on offer',
#        'Complete, relevant description information of products',
#        'Fast loading website speed of website and application',
#        'Reliability of the website or application',
#        'Quickness to complete purchase',
#        'Availability of several payment options', 'Speedy order delivery ',
#        'Privacy of customers’ information',
#        'Security of customer financial information',
#        'Perceived Trustworthiness',
#        'Presence of online assistance through multi-channel',
#        'Longer time to get logged in (promotion, sales period)',
#        'Longer time in displaying graphics and photos (promotion, sales period)',
#        'Late declaration of price (promotion, sales period)',
#        'Longer page loading time (promotion, sales period)',
#        'Limited mode of payment on most products (promotion, sales period)',
#        'Longer delivery period', 'Change in website/Application design',
#        'Frequent disruption when moving from one page to another',
#        'Website is as efficient as before',
#        'Which of the Indian online retailer would you recommend to a friend?'],
#       dtype='object')

# %%
len(dataset.columns) # Totally we have 71 columns
# Out:
# 71

# %% [markdown]
# ### Observation :
#
# - In the above dataset is having more feature so we need to understand which one relevant.
#
# - The column name is lengthy so we can rename that for our understand.
#
# - We are not seeing any target variable and as per the problem statment we need to analyse and find the insights from this data.
#
# - In the end of data analse we will decide we need to model or not.

# %%
dataset.shape
# Out:
# (269, 71)

# %%
# Checking types of dataset we have
pd.set_option('display.max_rows',None)

DataType = pd.DataFrame({'Feature':dataset.columns,'DataType':dataset.dtypes})
DataType.set_index('Feature',inplace=True)
DataType
# Out:
#                                                    DataType
# Feature
# 1Gender of respondent                                object
# 2 How old are you?                                   object
# 3 Which city do you shop online from?                object
# 4 What is the Pin Code of where you shop online...    int64
# 5 Since How Long You are Shopping Online ?           object
# 6 How many times you have made an online purcha...   object
# 7 How do you access the internet while shopping...   object
# 8 Which device do you use to access the online ...   object
# 9 What is the screen size of your mobile device...   object
# 10 What is the operating system (OS) of your de...   object
# 11 What browser do you run on your device to ac...   object
# 12 Which channel did you follow to arrive at yo...   object
# 13 After first visit, how do you reach the onli...   object
# 14 How much time do you explore the e- retail s...   object
# 15 What is your preferred payment Option?\t\t\t...   object
# 16 How frequently do you abandon (selecting an ...   object
# 17 Why did you abandon the “Bag”, “Shopping Car...   object
# 18 The content on the website must be easy to r...   object
# 19 Information on similar product to the one hi...   object
# 20 Complete information on listed seller and pr...   object
# 21 All relevant information on listed products ...   object
# 22 Ease of navigation in website                     object
# 23 Loading and processing speed                      object
# 24 User friendly Interface of the website            object
# 25 Convenient Payment methods                        object
# 26 Trust that the online retail store will fulf...   object
# 27 Empathy (readiness to assist with queries) t...   object
# 28 Being able to guarantee the privacy of the c...   object
# 29 Responsiveness, availability of several comm...   object
# 30 Online shopping gives monetary benefit and d...   object
# 31 Enjoyment is derived from shopping online         object
# 32 Shopping online is convenient and flexible        object
# 33 Return and replacement policy of the e-taile...   object
# 34 Gaining access to loyalty programs is a bene...   object
# 35 Displaying quality Information on the websit...   object
# 36 User derive satisfaction while shopping on a...   object
# 37 Net Benefit derived from shopping online can...   object
# 38 User satisfaction cannot exist without trust      object
# 39 Offering a wide variety of listed product in...   object
# 40 Provision of complete and relevant product i...   object
# 41 Monetary savings                                  object
# 42 The Convenience of patronizing the online re...   object
# 43 Shopping on the website gives you the sense ...   object
# 44 Shopping on your preferred e-tailer enhances...   object
# 45 You feel gratification shopping on your favo...   object
# 46 Shopping on the website helps you fulfill ce...   object
# 47 Getting value for money spent                     object
# From the following, tick any (or all) of the on...   object
# Easy to use website or application                   object
# Visual appealing web-page layout                     object
# Wild variety of product on offer                     object
# Complete, relevant description information of p...   object
# Fast loading website speed of website and appli...   object
# Reliability of the website or application            object
# Quickness to complete purchase                       object
# Availability of several payment options              object
# Speedy order delivery                                object
# Privacy of customers’ information                    object
# Security of customer financial information           object
# Perceived Trustworthiness                            object
# Presence of online assistance through multi-cha...   object
# Longer time to get logged in (promotion, sales ...   object
# Longer time in displaying graphics and photos (...   object
# Late declaration of price (promotion, sales per...   object
# Longer page loading time (promotion, sales period)   object
# Limited mode of payment on most products (promo...   object
# Longer delivery period                               object
# Change in website/Application design                 object
# Frequent disruption when moving from one page t...   object
# Website is as efficient as before                    object
# Which of the Indian online retailer would you r...   object

# %%
DataType.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='DataType'>

# %% [markdown]
# ##### All value almost Object only but pincode is in integer as we know ML model only understand numerical value so we need to use some encoder to convert the string value to numerical form.

# %% [markdown]
# ### Checking Null value present in the dataset

# %%
plt.figure(figsize=(30,8))
# x = dataset.isnull().iloc[0,:]
ax = sns.heatmap(dataset.isnull())
#ax.set()
ax.set_xticklabels(ax.get_xmajorticklabels(),fontsize = 10)
plt.show()

# %% [markdown]
# **If null value is present in the data mean color will be differ in the each column So we are not seeing any changes in heatmap color so their is not null value in the dataset**

# %%
# We want see what are the unique category is present in the data so that i can clean accordingly

data =dataset.copy() # taking copy of original dataset
cat_data = [feature for feature in data.columns if data[feature].dtype == 'O']

#creating dataframe
Unique_feature = {}
Unique_feature['Feature'] = []
Unique_feature['length']=[]
Unique_feature['category']=[]

for i in cat_data:
    Unique_feature['Feature'].append(i)
    Unique_feature['length'].append(len(data[i].unique()))
    Unique_feature['category'].append(data[i].unique())

unique_cat = pd.DataFrame(Unique_feature)
unique_cat
# Out:
#                                               Feature  length  \
# 0                               1Gender of respondent       2
# 1                                 2 How old are you?        5
# 2               3 Which city do you shop online from?      11
# 3          5 Since How Long You are Shopping Online ?       5
# 4   6 How many times you have made an online purch...       6
# 5   7 How do you access the internet while shoppin...       4
# 6   8 Which device do you use to access the online...       4
# 7   9 What is the screen size of your mobile devic...       4
# 8   10 What is the operating system (OS) of your d...       3
# 9   11 What browser do you run on your device to a...       4
# 10  12 Which channel did you follow to arrive at y...       3
# 11  13 After first visit, how do you reach the onl...       5
# 12  14 How much time do you explore the e- retail ...       5
# 13  15 What is your preferred payment Option?\t\t\...       3
# 14  16 How frequently do you abandon (selecting an...       4
# 15  17 Why did you abandon the “Bag”, “Shopping Ca...       5
# 16  18 The content on the website must be easy to ...       4
# 17  19 Information on similar product to the one h...       4
# 18  20 Complete information on listed seller and p...       5
# 19  21 All relevant information on listed products...       4
# 20                   22 Ease of navigation in website       4
# 21                    23 Loading and processing speed       5
# 22          24 User friendly Interface of the website       5
# 23                      25 Convenient Payment methods       3
# 24  26 Trust that the online retail store will ful...       4
# 25  27 Empathy (readiness to assist with queries) ...       4
# 26  28 Being able to guarantee the privacy of the ...       3
# 27  29 Responsiveness, availability of several com...       4
# 28  30 Online shopping gives monetary benefit and ...       5
# 29       31 Enjoyment is derived from shopping online       5
# 30      32 Shopping online is convenient and flexible       4
# 31  33 Return and replacement policy of the e-tail...       3
# 32  34 Gaining access to loyalty programs is a ben...       5
# 33  35 Displaying quality Information on the websi...       3
# 34  36 User derive satisfaction while shopping on ...       3
# 35  37 Net Benefit derived from shopping online ca...       4
# 36    38 User satisfaction cannot exist without trust       5
# 37  39 Offering a wide variety of listed product i...       4
# 38  40 Provision of complete and relevant product ...       4
# 39                                41 Monetary savings       4
# 40  42 The Convenience of patronizing the online r...       3
# 41  43 Shopping on the website gives you the sense...       5
# 42  44 Shopping on your preferred e-tailer enhance...       5
# 43  45 You feel gratification shopping on your fav...       5
# 44  46 Shopping on the website helps you fulfill c...       5
# 45                   47 Getting value for money spent       3
# 46  From the following, tick any (or all) of the o...       9
# 47                 Easy to use website or application      10
# 48                   Visual appealing web-page layout      10
# 49                   Wild variety of product on offer       9
# 50  Complete, relevant description information of ...      11
# 51  Fast loading website speed of website and appl...      10
# 52          Reliability of the website or application      10
# 53                     Quickness to complete purchase       9
# 54            Availability of several payment options      11
# 55                             Speedy order delivery        6
# 56                  Privacy of customers’ information      11
# 57         Security of customer financial information      11
# 58                          Perceived Trustworthiness       9
# 59  Presence of online assistance through multi-ch...      10
# 60  Longer time to get logged in (promotion, sales...      10
# 61  Longer time in displaying graphics and photos ...      10
# 62  Late declaration of price (promotion, sales pe...       8
# 63  Longer page loading time (promotion, sales per...      11
# 64  Limited mode of payment on most products (prom...       8
# 65                             Longer delivery period       6
# 66               Change in website/Application design       7
# 67  Frequent disruption when moving from one page ...       8
# 68                  Website is as efficient as before       8
# 69  Which of the Indian online retailer would you ...       8
#
#                                              category
# 0                                      [Male, Female]
# 1   [31-40 years, 21-30 years, 41-50 yaers, Less t...
# 2   [Delhi, Greater Noida, Karnal , Bangalore , No...
# 3   [Above 4 years, 3-4 years, 2-3 years, Less tha...
# 4   [31-40 times, 41 times and above, Less than 10...
# 5   [Dial-up, Wi-Fi, Mobile Internet, Mobile inter...
# 6               [Desktop, Smartphone, Tablet, Laptop]
# 7          [Others, 4.7 inches, 5.5 inches, 5 inches]
# 8           [Window/windows Mobile, IOS/Mac, Android]
# 9     [Google chrome, Safari, Opera, Mozilla Firefox]
# 10  [Search Engine, Content Marketing, Display Adv...
# 11  [Search Engine, Via application, Direct URL, E...
# 12  [6-10 mins, more than 15 mins, 11-15 mins, 1-5...
# 13  [E-wallets (Paytm, Freecharge etc.), Credit/De...
# 14    [Sometimes, Very frequently, Never, Frequently]
# 15  [Lack of trust, Promo code not applicable, Bet...
# 16  [Agree (4), Strongly agree (5), Strongly disag...
# 17  [Indifferent (3), Strongly agree (5), Agree (4...
# 18  [Indifferent (3), Strongly agree (5), Agree (4...
# 19  [Agree (4), Strongly agree (5), Strongly disag...
# 20  [Agree (4), Strongly agree (5), Strongly disag...
# 21  [Strongly disagree (1), Strongly agree (5), Ag...
# 22  [Dis-agree (2), Strongly agree (5), Agree (4),...
# 23     [Dis-agree (2), Strongly agree (5), Agree (4)]
# 24  [Disagree (2), Strongly agree (5), Agree (4), ...
# 25  [Strongly agree (5), Agree (4), Strongly disag...
# 26   [Agree (4), Strongly agree (5), indifferent (3)]
# 27  [Agree (4), Strongly agree (5), indifferent (3...
# 28  [indifferent (3), Strongly agree (5), Agree (4...
# 29  [Strongly disagree (1), Strongly agree (5), in...
# 30  [Dis-agree (2), Strongly agree (5), indifferen...
# 31     [Dis-agree (2), Strongly agree (5), Agree (4)]
# 32  [Agree (4), Strongly agree (5), indifferent (3...
# 33   [indifferent (3), Strongly agree (5), Agree (4)]
# 34     [Strongly agree (5), Agree (4), Dis-agree (2)]
# 35  [Agree (4), Strongly agree (5), indifferent (3...
# 36  [Strongly agree (5), Agree (4), Strongly disag...
# 37  [indifferent (3), Strongly agree (5), Agree (4...
# 38  [indifferent (3), Strongly agree (5), Agree (4...
# 39  [Disagree (2), Strongly agree (5), Agree (4), ...
# 40   [indifferent (3), Agree (4), Strongly agree (5)]
# 41  [Agree (4), indifferent (3), Strongly agree (5...
# 42  [Agree (4), indifferent (3), Strongly agree (5...
# 43  [Strongly agree (5), indifferent (3), Agree (4...
# 44  [Agree (4), Strongly agree (5), indifferent (3...
# 45   [Strongly agree (5), Agree (4), indifferent (3)]
# 46  [Amazon.in, Paytm.com, Amazon.in, Flipkart.com...
# 47  [Paytm.com, Amazon.in, Flipkart.com, Myntra.co...
# 48  [Flipkart.com, Amazon.in, Myntra.com, Amazon.i...
# 49  [Flipkart.com, Flipkart.com, Myntra.com, Amazo...
# 50  [Snapdeal.com, Amazon.in, Flipkart.com, Myntra...
# 51  [Snapdeal.com, Amazon.in, Flipkart.com, Myntra...
# 52  [Paytm.com, Myntra.com, Amazon.in, Paytm.com, ...
# 53  [Paytm.com, Amazon.com, Flipkart.com, Myntra.c...
# 54  [Patym.com, Amazon.in, Flipkart.com, Myntra.co...
# 55  [Amazon.in, Amazon.in, Flipkart.com, Amazon.in...
# 56  [Amazon.in, Myntra.com, Amazon.in, Flipkart.co...
# 57  [Amazon.in, Myntra.com, Amazon.in, Paytm.com, ...
# 58  [Flipkart.com, Myntra.com, Amazon.in, Myntra.c...
# 59  [Paytm.com, Amazon.in, Flipkart.com, Myntra.co...
# 60  [Amazon.in, Amazon.in, Flipkart.com, Myntra.co...
# 61  [Amazon.in, Myntra.com, Myntra.com, Snapdeal.c...
# 62  [Flipkart.com, snapdeal.com, Myntra.com, Paytm...
# 63  [Flipkart.com, Snapdeal.com, Myntra.com, Paytm...
# 64  [Amazon.in, Snapdeal.com, Paytm.com, Amazon.in...
# 65  [Paytm.com, Snapdeal.com, Flipkart.com, Amazon...
# 66  [Flipkart.com, Amazon.in, Paytm.com, Amazon.in...
# 67  [Amazon.in, Myntra.com, Paytm.com, Amazon.in, ...
# 68  [Amazon.in, Amazon.in, Flipkart.com, Amazon.in...
# 69  [Flipkart.com, Amazon.in, Myntra.com, Amazon.i...

# %%
#ploting barchart to understand which column is having more categorical value 
plt.figure(figsize=(22,8))
sns.barplot(x=unique_cat.Feature.index,y=unique_cat.length)
# Out:
# <AxesSubplot:ylabel='length'>

# %%
unique_cat.length.sort_values(ascending=False)[:10].plot.bar()
# we are just checking top 10 highest categorical value to understand the data
# Out:
# <AxesSubplot:>

# %%
# Dealing each column and removing unnessary data from that dataframe

unique_cat.iloc[1,2]
# Out:
# array(['31-40 years', '21-30 years', '41-50 yaers', 'Less than 20 years',
#        '51 years and above'], dtype=object)

# %%
def age_scale(col):
    if col == ('Less than 20 years' or '21-30 years'):
        return "Young Age Adult"
    elif col == '21-30 years':
        return "Young Age Adult"
    elif col == ('31-40 years' or '41-50 yaers'):
        return "Middle Age Adult"
    elif col == ('51 years and above'):
        return "Old Age Adults"
    else:
        return None

# %%
data['2 How old are you? '].unique()
# Out:
# array(['31-40 years', '21-30 years', '41-50 yaers', 'Less than 20 years',
#        '51 years and above'], dtype=object)

# %%
"41-50 yaers" == ('31-40 years' or "41-50 yaers")
# Out:
# False

# %%
# Who is purchasing more in ecommerce

for i in cat_data:
    l = len(data[i].unique()) * 2
    plt.figure(figsize=(l,5))
    sns.countplot(data[i])

# %% [markdown]
# ### Need to handle dataset
#
# 1. Access internet Mobile Internet is repeated one we need merge.

# %%
plt.figure(figsize=(12,5))
data['7 How do you access the internet while shopping on-line?'] = data['7 How do you access the internet while shopping on-line?'].str.replace("Mobile internet","Mobile Internet")
sns.countplot(data['7 How do you access the internet while shopping on-line?'],hue=data['Which of the Indian online retailer would you recommend to a friend?'])
# Out:
# <AxesSubplot:xlabel='7 How do you access the internet while shopping on-line?', ylabel='count'>

# %%
plt.figure(figsize=(12,5))
sns.countplot(data['17 Why did you abandon the “Bag”, “Shopping Cart”?'])
# Out:
# <AxesSubplot:xlabel='17 Why did you abandon the “Bag”, “Shopping Cart”?', ylabel='count'>

# %%
plt.figure(figsize=(12,5))
sns.countplot(data=data,x='14 How much time do you explore the e- retail store before making a purchase decision?',
             hue=data['Which of the Indian online retailer would you recommend to a friend?'])
# Out:
# <AxesSubplot:xlabel='14 How much time do you explore the e- retail store before making a purchase decision?', ylabel='count'>

# %%
data.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you?',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?',
#        '10 What is the operating system (OS) of your device?',
#        '11 What browser do you run on your device to access the website?',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?',
#        '13 After first visit, how do you reach the online retail store?',
#        '14 How much time do you explore the e- retail store before making a purchase decision?',
#        '15 What is your preferred payment Option?',
#        '16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?',
#        '17 Why did you abandon the “Bag”, “Shopping Cart”?',
#        '18 The content on the website must be easy to read and understand',
#        '19 Information on similar product to the one highlighted  is important for product comparison',
#        '20 Complete information on listed seller and product being offered is important for purchase decision.',
#        '21 All relevant information on listed products must be stated clearly',
#        '22 Ease of navigation in website', '23 Loading and processing speed',
#        '24 User friendly Interface of the website',
#        '25 Convenient Payment methods',
#        '26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time',
#        '27 Empathy (readiness to assist with queries) towards the customers',
#        '28 Being able to guarantee the privacy of the customer',
#        '29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)',
#        '30 Online shopping gives monetary benefit and discounts',
#        '31 Enjoyment is derived from shopping online',
#        '32 Shopping online is convenient and flexible',
#        '33 Return and replacement policy of the e-tailer is important for purchase decision',
#        '34 Gaining access to loyalty programs is a benefit of shopping online',
#        '35 Displaying quality Information on the website improves satisfaction of customers',
#        '36 User derive satisfaction while shopping on a good quality website or application',
#        '37 Net Benefit derived from shopping online can lead to users satisfaction',
#        '38 User satisfaction cannot exist without trust',
#        '39 Offering a wide variety of listed product in several category',
#        '40 Provision of complete and relevant product information',
#        '41 Monetary savings',
#        '42 The Convenience of patronizing the online retailer',
#        '43 Shopping on the website gives you the sense of adventure',
#        '44 Shopping on your preferred e-tailer enhances your social status',
#        '45 You feel gratification shopping on your favorite e-tailer',
#        '46 Shopping on the website helps you fulfill certain roles',
#        '47 Getting value for money spent',
#        'From the following, tick any (or all) of the online retailers you have shopped from;',
#        'Easy to use website or application',
#        'Visual appealing web-page layout', 'Wild variety of product on offer',
#        'Complete, relevant description information of products',
#        'Fast loading website speed of website and application',
#        'Reliability of the website or application',
#        'Quickness to complete purchase',
#        'Availability of several payment options', 'Speedy order delivery',
#        'Privacy of customers’ information',
#        'Security of customer financial information',
#        'Perceived Trustworthiness',
#        'Presence of online assistance through multi-channel',
#        'Longer time to get logged in (promotion, sales period)',
#        'Longer time in displaying graphics and photos (promotion, sales period)',
#        'Late declaration of price (promotion, sales period)',
#        'Longer page loading time (promotion, sales period)',
#        'Limited mode of payment on most products (promotion, sales period)',
#        'Longer delivery period', 'Change in website/Application design',
#        'Frequent disruption when moving from one page to another',
#        'Website is as efficient as before',
#        'Which of the Indian online retailer would you recommend to a friend?'],
#       dtype='object')

# %%
data['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '].unique()
# Out:
# array(['E-wallets (Paytm, Freecharge etc.)', 'Credit/Debit cards',
#        'Cash on delivery (CoD)'], dtype=object)

# %%
data.columns = data.columns.str.replace("\\t","").str.strip()

# %%
data.tail()
# Out:
#     1Gender of respondent  2 How old are you?  \
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 264                                 Solan
# 265                             Ghaziabad
# 266                            Bangalore
# 267                                 Solan
# 268                             Ghaziabad
#
#      4 What is the Pin Code of where you shop online from?  \
# 264                                             173212
# 265                                             201008
# 266                                             560010
# 267                                             173229
# 268                                             201009
#
#     5 Since How Long You are Shopping Online ?  \
# 264                                  1-2 years
# 265                                  1-2 years
# 266                                  2-3 years
# 267                                  2-3 years
# 268                                  2-3 years
#
#     6 How many times you have made an online purchase in the past 1 year?  \
# 264                                 Less than 10 times
# 265                                        31-40 times
# 266                                 Less than 10 times
# 267                                 Less than 10 times
# 268                                        31-40 times
#
#     7 How do you access the internet while shopping on-line?  \
# 264                                    Mobile Internet
# 265                                    Mobile Internet
# 266                                    Mobile internet
# 267                                              Wi-Fi
# 268                                    Mobile Internet
#
#     8 Which device do you use to access the online shopping?  \
# 264                                         Smartphone
# 265                                         Smartphone
# 266                                             Laptop
# 267                                         Smartphone
# 268                                         Smartphone
#
#     9 What is the screen size of your mobile device?  \
# 264                                       5.5 inches
# 265                                           Others
# 266                                           Others
# 267                                       5.5 inches
# 268                                       5.5 inches
#
#     10 What is the operating system (OS) of your device?  \
# 264                                            Android
# 265                                            Android
# 266                              Window/windows Mobile
# 267                                            Android
# 268                                            Android
#
#     11 What browser do you run on your device to access the website?  \
# 264                                              Opera
# 265                                      Google chrome
# 266                                      Google chrome
# 267                                      Google chrome
# 268                                      Google chrome
#
#     12 Which channel did you follow to arrive at your favorite online store for the first time?  \
# 264                                    Display Adverts
# 265                                      Search Engine
# 266                                      Search Engine
# 267                                      Search Engine
# 268                                      Search Engine
#
#     13 After first visit, how do you reach the online retail store?  \
# 264                                       Social Media
# 265                                    Via application
# 266                                      Search Engine
# 267                                         Direct URL
# 268                                    Via application
#
#     14 How much time do you explore the e- retail store before making a purchase decision?  \
# 264                                  more than 15 mins
# 265                                    Less than 1 min
# 266                                  more than 15 mins
# 267                                           1-5 mins
# 268                                         11-15 mins
#
#     15 What is your preferred payment Option?  \
# 264                    Cash on delivery (CoD)
# 265                    Cash on delivery (CoD)
# 266                        Credit/Debit cards
# 267                    Cash on delivery (CoD)
# 268                    Cash on delivery (CoD)
#
#     16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?  \
# 264                                              Never
# 265                                          Sometimes
# 266                                          Sometimes
# 267                                          Sometimes
# 268                                              Never
#
#     17 Why did you abandon the “Bag”, “Shopping Cart”?  \
# 264                           Better alternative offer
# 265                                    Change in price
# 266                           Better alternative offer
# 267                       No preferred mode of payment
# 268                          Promo code not applicable
#
#     18 The content on the website must be easy to read and understand  \
# 264                                          Agree (4)
# 265                                 Strongly agree (5)
# 266                                 Strongly agree (5)
# 267                                 Strongly agree (5)
# 268                                 Strongly agree (5)
#
#     19 Information on similar product to the one highlighted  is important for product comparison  \
# 264                                          Agree (4)
# 265                                 Strongly agree (5)
# 266                                 Strongly agree (5)
# 267                                          Agree (4)
# 268                                 Strongly agree (5)
#
#     20 Complete information on listed seller and product being offered is important for purchase decision.  \
# 264                                          Agree (4)
# 265                                 Strongly agree (5)
# 266                                          Agree (4)
# 267                                 Strongly agree (5)
# 268                                 Strongly agree (5)
#
#     21 All relevant information on listed products must be stated clearly  \
# 264                                          Agree (4)
# 265                                 Strongly agree (5)
# 266                                          Agree (4)
# 267                                          Agree (4)
# 268                                 Strongly agree (5)
#
#     22 Ease of navigation in website 23 Loading and processing speed  \
# 264                        Agree (4)                       Agree (4)
# 265               Strongly agree (5)              Strongly agree (5)
# 266               Strongly agree (5)                       Agree (4)
# 267                        Agree (4)                       Agree (4)
# 268               Strongly agree (5)              Strongly agree (5)
#
#     24 User friendly Interface of the website 25 Convenient Payment methods  \
# 264                                 Agree (4)                     Agree (4)
# 265                        Strongly agree (5)            Strongly agree (5)
# 266                                 Agree (4)            Strongly agree (5)
# 267                        Strongly agree (5)            Strongly agree (5)
# 268                        Strongly agree (5)            Strongly agree (5)
#
#     26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time  \
# 264                                          Agree (4)
# 265                                 Strongly agree (5)
# 266                                          Agree (4)
# 267                                 Strongly agree (5)
# 268                                 Strongly agree (5)
#
#     27 Empathy (readiness to assist with queries) towards the customers  \
# 264                                          Agree (4)
# 265                                 Strongly agree (5)
# 266                                    indifferent (3)
# 267                                 Strongly agree (5)
# 268                                 Strongly agree (5)
#
#     28 Being able to guarantee the privacy of the customer  \
# 264                                          Agree (4)
# 265                                 Strongly agree (5)
# 266                                    indifferent (3)
# 267                                 Strongly agree (5)
# 268                                 Strongly agree (5)
#
#     29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)  \
# 264                                          Agree (4)
# 265                                 Strongly agree (5)
# 266                                          Agree (4)
# 267                                 Strongly agree (5)
# 268                                 Strongly agree (5)
#
#     30 Online shopping gives monetary benefit and discounts  \
# 264                                    indifferent (3)
# 265                                 Strongly agree (5)
# 266                                          Agree (4)
# 267                                 Strongly agree (5)
# 268                                 Strongly agree (5)
#
#     31 Enjoyment is derived from shopping online  \
# 264                              indifferent (3)
# 265                           Strongly agree (5)
# 266                              indifferent (3)
# 267                                    Agree (4)
# 268                           Strongly agree (5)
#
#     32 Shopping online is convenient and flexible  \
# 264                               indifferent (3)
# 265                            Strongly agree (5)
# 266                                     Agree (4)
# 267                            Strongly agree (5)
# 268                            Strongly agree (5)
#
#     33 Return and replacement policy of the e-tailer is important for purchase decision  \
# 264                                      Dis-agree (2)
# 265                                 Strongly agree (5)
# 266                                 Strongly agree (5)
# 267                                          Agree (4)
# 268                                 Strongly agree (5)
#
#     34 Gaining access to loyalty programs is a benefit of shopping online  \
# 264                                    indifferent (3)
# 265                                 Strongly agree (5)
# 266                                    indifferent (3)
# 267                                          Agree (4)
# 268                                 Strongly agree (5)
#
#     35 Displaying quality Information on the website improves satisfaction of customers  \
# 264                                    indifferent (3)
# 265                                 Strongly agree (5)
# 266                                          Agree (4)
# 267                                 Strongly agree (5)
# 268                                          Agree (4)
#
#     36 User derive satisfaction while shopping on a good quality website or application  \
# 264                                      Dis-agree (2)
# 265                                 Strongly agree (5)
# 266                                          Agree (4)
# 267                                 Strongly agree (5)
# 268                                 Strongly agree (5)
#
#     37 Net Benefit derived from shopping online can lead to users satisfaction  \
# 264                                    indifferent (3)
# 265                                 Strongly agree (5)
# 266                                          Agree (4)
# 267                                 Strongly agree (5)
# 268                                 Strongly agree (5)
#
#     38 User satisfaction cannot exist without trust  \
# 264                                       Agree (4)
# 265                              Strongly agree (5)
# 266                                       Agree (4)
# 267                              Strongly agree (5)
# 268                              Strongly agree (5)
#
#     39 Offering a wide variety of listed product in several category  \
# 264                                          Agree (4)
# 265                                 Strongly agree (5)
# 266                                    indifferent (3)
# 267                                 Strongly agree (5)
# 268                                 Strongly agree (5)
#
#     40 Provision of complete and relevant product information  \
# 264                                    indifferent (3)
# 265                                 Strongly agree (5)
# 266                                 Strongly agree (5)
# 267                                          Agree (4)
# 268                                 Strongly agree (5)
#
#     41 Monetary savings 42 The Convenience of patronizing the online retailer  \
# 264        Disagree (2)                                    indifferent (3)
# 265  Strongly agree (5)                                 Strongly agree (5)
# 266           Agree (4)                                          Agree (4)
# 267           Agree (4)                                          Agree (4)
# 268  Strongly agree (5)                                 Strongly agree (5)
#
#     43 Shopping on the website gives you the sense of adventure  \
# 264                                      Dis-agree (2)
# 265                                 Strongly agree (5)
# 266                                      Dis-agree (2)
# 267                                          Agree (4)
# 268                                 Strongly agree (5)
#
#     44 Shopping on your preferred e-tailer enhances your social status  \
# 264                                          Agree (4)
# 265                                 Strongly agree (5)
# 266                                    indifferent (3)
# 267                                    indifferent (3)
# 268                                 Strongly agree (5)
#
#     45 You feel gratification shopping on your favorite e-tailer  \
# 264                                    indifferent (3)
# 265                                 Strongly agree (5)
# 266                                          Agree (4)
# 267                                    indifferent (3)
# 268                                 Strongly agree (5)
#
#     46 Shopping on the website helps you fulfill certain roles  \
# 264                                          Agree (4)
# 265                                 Strongly agree (5)
# 266                                          Agree (4)
# 267                                          Agree (4)
# 268                                 Strongly agree (5)
#
#     47 Getting value for money spent  \
# 264                  indifferent (3)
# 265               Strongly agree (5)
# 266                        Agree (4)
# 267                  indifferent (3)
# 268               Strongly agree (5)
#
#     From the following, tick any (or all) of the online retailers you have shopped from;  \
# 264                                          Amazon.in
# 265                            Amazon.in, Flipkart.com
# 266              Amazon.in, Flipkart.com, Snapdeal.com
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#                     Easy to use website or application  \
# 264                                          Amazon.in
# 265                                       Flipkart.com
# 266                                          Amazon.in
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#                       Visual appealing web-page layout  \
# 264                                          Amazon.in
# 265                                          Amazon.in
# 266                                          Amazon.in
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#                       Wild variety of product on offer  \
# 264                                          Amazon.in
# 265                                          Amazon.in
# 266                                          Amazon.in
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#     Complete, relevant description information of products  \
# 264                                          Amazon.in
# 265                                       Flipkart.com
# 266                                          Amazon.in
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#     Fast loading website speed of website and application  \
# 264                                          Amazon.in
# 265                                       Flipkart.com
# 266                                          Amazon.in
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#              Reliability of the website or application  \
# 264                                          Amazon.in
# 265                                       Flipkart.com
# 266                                          Amazon.in
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#          Quickness to complete purchase  \
# 264                          Amazon.com
# 265                        Flipkart.com
# 266                          Amazon.com
# 267  Flipkart.com, Myntra.com, Snapdeal
# 268                          Amazon.com
#
#     Availability of several payment options  \
# 264                               Amazon.in
# 265                            Flipkart.com
# 266                 Amazon.in, Flipkart.com
# 267  Flipkart.com, Myntra.com, Snapdeal.com
# 268                               Amazon.in
#
#                       Speedy order delivery  \
# 264                               Amazon.in
# 265                            Flipkart.com
# 266                               Amazon.in
# 267  Flipkart.com, Myntra.com, Snapdeal.com
# 268                               Amazon.in
#
#                      Privacy of customers’ information  \
# 264                                          Amazon.in
# 265                                       Flipkart.com
# 266                                          Amazon.in
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#             Security of customer financial information  \
# 264                                          Amazon.in
# 265                                       Flipkart.com
# 266                                          Amazon.in
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#                              Perceived Trustworthiness  \
# 264                                          Amazon.in
# 265                                       Flipkart.com
# 266                                          Amazon.in
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#     Presence of online assistance through multi-channel  \
# 264                                          Amazon.in
# 265                                       Flipkart.com
# 266                                          Amazon.in
# 267      Amazon.in, Flipkart.com, Myntra.com, Snapdeal
# 268                                          Amazon.in
#
#     Longer time to get logged in (promotion, sales period)  \
# 264                                          Amazon.in
# 265                                       Flipkart.com
# 266                                          Amazon.in
# 267                                          Amazon.in
# 268                                          Amazon.in
#
#     Longer time in displaying graphics and photos (promotion, sales period)  \
# 264                                          Amazon.in
# 265                                       Flipkart.com
# 266                                       Snapdeal.com
# 267                Amazon.in, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#     Late declaration of price (promotion, sales period)  \
# 264                                          Amazon.in
# 265                                       Flipkart.com
# 266                                          Amazon.in
# 267                                          Amazon.in
# 268                                          Amazon.in
#
#     Longer page loading time (promotion, sales period)  \
# 264                                          Amazon.in
# 265                                       Flipkart.com
# 266                                       Snapdeal.com
# 267                            Amazon.in, Snapdeal.com
# 268                                          Amazon.in
#
#     Limited mode of payment on most products (promotion, sales period)  \
# 264                                          Amazon.in
# 265                                       Flipkart.com
# 266                                       Snapdeal.com
# 267                                          Amazon.in
# 268                                          Amazon.in
#
#     Longer delivery period Change in website/Application design  \
# 264              Amazon.in                            Amazon.in
# 265           Flipkart.com                         Flipkart.com
# 266           Snapdeal.com                         Snapdeal.com
# 267              Amazon.in                            Amazon.in
# 268              Amazon.in                            Amazon.in
#
#     Frequent disruption when moving from one page to another  \
# 264                                          Amazon.in
# 265                                       Flipkart.com
# 266                                       Snapdeal.com
# 267                           Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#     Website is as efficient as before  \
# 264                         Amazon.in
# 265                      Flipkart.com
# 266                         Amazon.in
# 267          Myntra.com, Snapdeal.com
# 268                         Amazon.in
#
#     Which of the Indian online retailer would you recommend to a friend?
# 264                                          Amazon.in
# 265                                       Flipkart.com
# 266                                          Amazon.in
# 267                                          Amazon.in
# 268                                          Amazon.in

# %%
data['2 How old are you?'].unique()
# Out:
# array(['31-40 years', '21-30 years', '41-50 yaers', 'Less than 20 years',
#        '51 years and above'], dtype=object)

# %%
def renameColumn(col): 
    if col == 'Less than 20 years':
        return '< 20 years'
    elif col == '21-30 years':
        return '21-30 years'
    elif col == '31-40 years':
        return '31-40 years'
    elif col == '41-50 yaers':
        return '41-50 years'
    elif '51 years and above':
        return '51 > years'
    else:
        return '0'

# %%
datacopy =  data.copy()

data['2 How old are you?'] = datacopy['2 How old are you?'].apply(renameColumn)

# %%
# Understanding some insights from data
plt.figure()
data.groupby(['1Gender of respondent','2 How old are you?']).max().plot(kind='bar',legend=False)
# Out:
# <AxesSubplot:xlabel='1Gender of respondent,2 How old are you?'>

# %% [markdown]
# ### Observation :
#
# 1. In male category age between 21 - 30 years category people mostly purchasing online.
#
# 2. In female category only 31 - 40 years is less interested on online.

# %%
pd.crosstab(data['24 User friendly Interface of the website'],data['Easy to use website or application'])
# Out:
# Easy to use website or application         Amazon.in  Amazon.in, Flipkart.com  \
# 24 User friendly Interface of the website
# Agree (4)                                         16                        7
# Dis-agree (2)                                      0                        0
# Indifferent (3)                                    5                        0
# Strongly agree (5)                                 8                       19
# Strongly disagree (1)                              0                       18
#
# Easy to use website or application         Amazon.in, Flipkart.com, Myntra.com  \
# 24 User friendly Interface of the website
# Agree (4)                                                                    0
# Dis-agree (2)                                                                0
# Indifferent (3)                                                              0
# Strongly agree (5)                                                          19
# Strongly disagree (1)                                                        0
#
# Easy to use website or application         Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com  \
# 24 User friendly Interface of the website
# Agree (4)                                                                                  0
# Dis-agree (2)                                                                              0
# Indifferent (3)                                                                            0
# Strongly agree (5)                                                                        44
# Strongly disagree (1)                                                                      0
#
# Easy to use website or application         Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com  \
# 24 User friendly Interface of the website
# Agree (4)                                                                                  0
# Dis-agree (2)                                                                              0
# Indifferent (3)                                                                            0
# Strongly agree (5)                                                                        64
# Strongly disagree (1)                                                                      0
#
# Easy to use website or application         Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com  \
# 24 User friendly Interface of the website
# Agree (4)                                                                                22
# Dis-agree (2)                                                                             0
# Indifferent (3)                                                                           0
# Strongly agree (5)                                                                        0
# Strongly disagree (1)                                                                     0
#
# Easy to use website or application         Amazon.in, Paytm.com  \
# 24 User friendly Interface of the website
# Agree (4)                                                     0
# Dis-agree (2)                                                 0
# Indifferent (3)                                               0
# Strongly agree (5)                                            7
# Strongly disagree (1)                                         0
#
# Easy to use website or application         Amazon.in, Paytm.com, Myntra.com  \
# 24 User friendly Interface of the website
# Agree (4)                                                                 0
# Dis-agree (2)                                                             0
# Indifferent (3)                                                           0
# Strongly agree (5)                                                       20
# Strongly disagree (1)                                                     0
#
# Easy to use website or application         Flipkart.com  Paytm.com
# 24 User friendly Interface of the website
# Agree (4)                                             0          0
# Dis-agree (2)                                         0         12
# Indifferent (3)                                       0          0
# Strongly agree (5)                                    8          0
# Strongly disagree (1)                                 0          0

# %% [markdown]
# #### most of the people preference is Amazon because of rich user interface

# %% [markdown]
# ### Observation using the above plot :
#
# 1. We don't have any target variable in this dataset , So we are assuming consumers most prefered categorish from that we can get to know some information.
#
# 2. **Gender Responent** most of the respondent is female and generally it is correct
#
# 3. In the age category **20 to 50 years**  highest customer is there.
#
# 4. In this dataset most of the customer from north india.**Delhi** is repeating in different name state and city is mixed
#
# 5. In 269 customer almost half of the customer is more than 4 years.
#
# 6. Most of the customer using mobile internet
#
# 7. Smartphone prepared by consumer or customer.
#
# 8. Google chrome browser is mostly used by customer.
#
# 9. Most of the customer taking more time to take decision before purchase.
#
# 10. Customer preffered for EMI kind payment mode. Buy now pay later policies.
#
# 11. Most of the customer using mobile network and Amazon is fast in that.
#
# 12. Why did you abandon the “Bag”, “Shopping Cart”? - People waiting of better offer.
